# %%
movies=["fast5","kaithi","vikram","kgf2","spiderman"]
print(f" first movie is {movies[0]}")
print(f" last movie is {movies[-1]}")
print(f"third movie is {movies[2]}")
# Out:
#  first movie is fast5
#  last movie is kgf2
# third movie is vikram
