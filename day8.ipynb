# %%
import matplotlib.pyplot as plt
#import seaborn as sns
import numpy as np  
import pandas as pd

# %%
#line plot
x = [1, 3, 4, 5]
y = [2, 6, 8, 10]
plt.figure(figsize=(8, 5))
plt.plot(x, y)
plt.title('Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')    
plt.show()
